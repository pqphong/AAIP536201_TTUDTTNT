# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
df = pd.read_csv('data1.csv')
#x = df['x'].values
x = df.values[:,0]
#y = df['y'].values
y = df.values[:,-1]
y = np.reshape(y,(len(y),1)) #mx1
plt.scatter(x,y)
x = np.array([np.ones(len(x)),x],dtype='float') #2xm
x = x.T #mx2

# %%
x.shape
# Out:
# (100, 2)

# %%
ite = 100 #iteration
lr = 0.0003 #learning rate
m = len(y)
J=np.zeros(ite)
np.random.seed(1)
theta = np.random.rand(2,1) #theta: 2x1
h = np.dot(x,theta) # h: mx2.2x1 = mx1
for i in range(ite):
    theta = theta - (lr/m)*(np.dot((x.T),(h-y))) # 2xm.mx1 = 2x1
    h = np.dot(x,theta)
    J[i]=(1/(2*m))*np.dot((h-y).T,(h-y)) # 1xm.mx1 = 1x1
plt.plot(J)
# Out:
# C:\Users\PHONGPHAM\AppData\Local\Temp\ipykernel_27368\1629554136.py:11: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   J[i]=(1/(2*m))*np.dot((h-y).T,(h-y)) # 1xm.mx1 = 1x1

# %%
np.random.seed(3)
theta = np.random.rand(2,1) #theta: 2x1
print(theta)
# Out:
# [[0.5507979 ]
#  [0.70814782]]

# %%
a = np.arange(100)
b = theta[0]+theta[1]*a
plt.scatter(x[:,1],y)
plt.plot(b,'r')

# %%
plt.plot(J)

# %%
theta

# %%
print(theta)
